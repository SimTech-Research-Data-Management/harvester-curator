# %%
# Run crawler.py

# %%
# %run -i "crawler.py"
# Out:
# ----- A simple example of using crawler in a given directory ----
#
# All files found by crawler in the directory:
# ...

# %%
# Run parser.py

# %%
# %run -i "parser.py"

# %%
# Run harvester.py

# %%
import os
#import pyvista as pv
#pv.set_jupyter_backend('trame')

# %run -i "harvester.py"
# Out:
# ----- A simple example of using harvester to extract metadata from all files in a given directory ----
#
# Start havesting metadata from files under the given path /Users/wangfg/Documents/myDataProject/myWork/zusammenWork/darus_data_harvester_V2/example...
#
#
#
# ***Please note that currently there are no parsers to parse vtm and wrl files found under the given path.
#
# List of unparsed files: ['/Users/wangfg/Documents/myDataProject/myWork/zusammenWork/darus_data_harvester_V2/example/ex-blow_5.vtm', '/Users/wangfg/Documents/myDataProject/myWork/zusammenWork/darus_data_harvester_V2/example/Box.wrl', '/Users/wangfg/Documents/myDataProject/myWork/zusammenWork/darus_data_harvester_V2/example/bridge.wrl']
#
#
# ---*** Matadata harvester output ***---
#
# name: all parsed file groups
# file_group_names:
#   3D image files:
#     - glb
#     - obj
#     - ply
#     - stl
#   2D image files:
#     - jpg
#     - pgm
#     - png
#     - pnm
#     - ppm
#     - tif
#   vtk files:
# ...
