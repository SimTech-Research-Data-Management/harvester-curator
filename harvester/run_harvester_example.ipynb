# %%
# Run crawler.py

# %%
# %run -i "crawler.py"
# Out:
# ----- A simple example of using crawler in a given directory ----
#
# All files found by crawler in the directory:
# ...

# %%
# Run parser.py

# %%
# %run -i "parser.py"

# %%
# Run harvester.py

# %%
import os
# %run -i "harvester.py"
# Out:
# ----- A simple example of using harvester to extract metadata from all files in a given directory ----
#
# Start havesting metadata from files under the given path /Users/wangfg/Documents/myDataProject/RDM_New/darus_data_harvester/example
#
# ---*** Matadata harvester output ***---
#
# name: all parsed file groups
# file_group_names:
#   vtk files:
#     - vtu
#     - vtk
#     - ply
#     - pvtu
#     - vti
#     - obj
#   txt files:
#     - txt
#   xml files:
#     - xml
# groups:
#   - name: vtk files
#     files:
#       - name: test_mesh.vtu
#         path: /Users/wangfg/Documents/myDataProject/RDM_New/darus_data_harvester/example/test_mesh.vtu
#         metadata:
#           dataset type:
#             - UnstructuredGrid
#           number of points:
#             - 7
#           number of cells:
#             - 5
#       - name: 00_raw_binary.vtu
#         path: /Users/wangfg/Documents/myDataProject/RDM_New/darus_data_harvester/example/00_raw_binary.vtu
#         metadata:
# ...
