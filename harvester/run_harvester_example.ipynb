# %%
# Run crawler.py

# %%
# %run -i "crawler.py"
# Out:
# ----- A simple example of using crawler in a given directory ----
#
# All files found by crawler in the directory:
# ...

# %%
# Run parser.py

# %%
# %run -i "parser.py"

# %%
# Run harvester.py

# %%
import os
#import pyvista as pv
#pv.set_jupyter_backend('trame')

# %run -i "harvester.py"
# Out:
# ----- A simple example of using harvester to extract metadata from all files in a given directory ----
#
# Start havesting metadata from files under the given path /Users/wangfg/Documents/myDataProject/RDM_New/darus_data_harvester/example
#
# file name: test_mesh.vtu
# meta properties extracted:
# UnstructuredGrid (0x17fcb4520)
#   N Cells:    5
#   N Points:   7
#   X Bounds:   0.000e+00, 2.000e+00
#   Y Bounds:   0.000e+00, 1.000e+00
#   Z Bounds:   0.000e+00, 0.000e+00
#   N Arrays:   4
#
# file name: 00_raw_binary.vtu
# meta properties extracted:
# UnstructuredGrid (0x17fcb44c0)
#   N Cells:    162
#   N Points:   64
#   X Bounds:   0.000e+00, 1.000e+00
#   Y Bounds:   0.000e+00, 1.000e+00
#   Z Bounds:   0.000e+00, 1.000e+00
#   N Arrays:   1
#
# file name: vox8_binary_inline.vtu
# meta properties extracted:
# UnstructuredGrid (0x17fcb45e0)
#   N Cells:    8
#   N Points:   27
#   X Bounds:   0.000e+00, 2.000e+00
#   Y Bounds:   0.000e+00, 2.000e+00
# ...
