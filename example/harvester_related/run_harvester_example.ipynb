# %%
! python3 /home/sarbani/harvester-curator/darus_data_harvester/harvester/harvester.py --path /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder -v
# Out:
# Start havesting metadata from files under the given path /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder ...
#
#
#
# ***Please note that currently there are no parsers to parse gz, h4, h5, hdf5, txt, vtm, wrl and xml files found under the given path.
#
# List of unparsed files: ['/home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/avg152T1_RL_nifti.nii.gz', '/home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/MODB_ex1.h4', '/home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/test1.h5', '/home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/NEONDSTowerTemperatureData.hdf5', '/home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/citation.txt', '/home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/sparsePoints.txt', '/home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5.vtm', '/home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/bridge.wrl', '/home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/Box.wrl', '/home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/author_name.xml', '/home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/book.xml']
#
#
# ---*** Metadata Harvester Output ***---
#
# Output will be written to: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/harvester_output/harvester_output.json
# /home/sarbani/.local/lib/python3.10/site-packages/sdRDM/base/datamodel.py:249: UserWarning: No 'URL' and 'Commit' specified. This model might not be re-usable.
#   warnings.warn(
# name: all parsed file groups
# file_group_names:
#   2D image files:
#     - bmp
#     - img
#     - jpg
#     - pgm
#     - png
#     - pnm
#     - ppm
#     - tif
#   3D image files:
#     - dcm
#     - dem
#     - exo
#     - facet
#     - glb
#     - obj
#     - ply
#     - slc
#     - stl
#   vtk files:
#     - hdf
#     - pvti
#     - pvtp
#     - pvtr
#     - pvtu
#     - vti
#     - vtk
#     - vtp
#     - vtr
#     - vts
#     - vtu
# groups:
#   - name: 2D image files
#     files:
#       - name: masonry.bmp
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/masonry.bmp
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 65536
#           number_of_cells:
#             - 65025
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - BMPImage
#           dimensions:
#             - - 256
#               - 256
#               - 1
#           spacing:
#             - - 1.0
#               - 1.0
#               - 1.0
#           mesh_bounds:
#             - - 0.0
#               - 255.0
#               - 0.0
#               - 255.0
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 127.5
#               - 127.5
#               - 0.0
#       - name: prostate.img
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/prostate.img
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 262144
#           number_of_cells:
#             - 261121
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - DICOMImage
#           dimensions:
#             - - 512
#               - 512
#               - 1
#           spacing:
#             - - 0.9375
#               - 0.9375
#               - 5.0
#           mesh_bounds:
#             - - 0.0
#               - 479.0625
#               - 0.0
#               - 479.0625
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 239.53125
#               - 239.53125
#               - 0.0
#       - name: earth.jpg
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/earth.jpg
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 2097152
#           number_of_cells:
#             - 2094081
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - JPEGImage
#           dimensions:
#             - - 2048
#               - 1024
#               - 1
#           spacing:
#             - - 1.0
#               - 1.0
#               - 1.0
#           mesh_bounds:
#             - - 0.0
#               - 2047.0
#               - 0.0
#               - 1023.0
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 1023.5
#               - 511.5
#               - 0.0
#       - name: binary.pgm
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/binary.pgm
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 254660
#           number_of_cells:
#             - 253638
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - ImageFile
#           dimensions:
#             - - 595
#               - 428
#               - 1
#           spacing:
#             - - 1.0
#               - 1.0
#               - 1.0
#           mesh_bounds:
#             - - 0.0
#               - 594.0
#               - 0.0
#               - 427.0
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 297.0
#               - 213.5
#               - 0.0
#       - name: uni_stuttgart.png
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/uni_stuttgart.png
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 58080
#           number_of_cells:
#             - 57509
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - PNGImage
#           dimensions:
#             - - 440
#               - 132
#               - 1
#           spacing:
#             - - 1.0
#               - 1.0
#               - 1.0
#           mesh_bounds:
#             - - 0.0
#               - 439.0
#               - 0.0
#               - 131.0
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 219.5
#               - 65.5
#               - 0.0
#       - name: Gourds.pnm
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/Gourds.pnm
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 307200
#           number_of_cells:
#             - 306081
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - ImageFile
#           dimensions:
#             - - 640
#               - 480
#               - 1
#           spacing:
#             - - 1.0
#               - 1.0
#               - 1.0
#           mesh_bounds:
#             - - 0.0
#               - 639.0
#               - 0.0
#               - 479.0
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 319.5
#               - 239.5
#               - 0.0
#       - name: earth.ppm
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/earth.ppm
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 131072
#           number_of_cells:
#             - 130305
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - ImageFile
#           dimensions:
#             - - 512
#               - 256
#               - 1
#           spacing:
#             - - 1.0
#               - 1.0
#               - 1.0
#           mesh_bounds:
#             - - 0.0
#               - 511.0
#               - 0.0
#               - 255.0
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 255.5
#               - 127.5
#               - 0.0
#       - name: ColorCells.tif
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ColorCells.tif
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 90000
#           number_of_cells:
#             - 89401
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - Tiff Scalars
#           dimensions:
#             - - 300
#               - 300
#               - 1
#           spacing:
#             - - 0.35277777777777775
#               - 0.35277777777777775
#               - 0.35277777777777775
#           mesh_bounds:
#             - - 0.0
#               - 105.48055555555554
#               - 0.0
#               - 105.48055555555554
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 52.74027777777777
#               - 52.74027777777777
#               - 0.0
#   - name: 3D image files
#     files:
#       - name: DICOM_KNEE.dcm
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/DICOM_KNEE.dcm
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 262144
#           number_of_cells:
#             - 261121
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - DICOMImage
#           dimensions:
#             - - 512
#               - 512
#               - 1
#           spacing:
#             - - 0.42969998717308044
#               - 0.42969998717308044
#               - 0.800000011920929
#           mesh_bounds:
#             - - 0.0
#               - 219.5766934454441
#               - 0.0
#               - 219.5766934454441
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 109.78834672272205
#               - 109.78834672272205
#               - 0.0
#       - name: SainteHelens.dem
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/SainteHelens.dem
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 152709
#           number_of_cells:
#             - 151916
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - Elevation
#           dimensions:
#             - - 327
#               - 467
#               - 1
#           spacing:
#             - - 30.0
#               - 30.0
#               - 1.0
#           mesh_bounds:
#             - - 557945.0
#               - 567725.0
#               - 5107991.5
#               - 5121971.5
#               - 682.0
#               - 682.0
#           mesh_center:
#             - - 562835.0
#               - 5114981.5
#               - 682.0
#       - name: mesh_fs8.exo
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/mesh_fs8.exo
#         metadata:
#           dataset_type:
#             - MultiBlock
#           number_of_blocks:
#             - 8
#           mesh_bounds:
#             - - !!python/object/apply:numpy.core.multiarray.scalar
#                 - &id001 !!python/object/apply:numpy.dtype
#                   args:
#                     - f8
#                     - false
#                     - true
#                   state: !!python/tuple
#                     - 3
#                     - <
#                     - null
#                     - null
#                     - null
#                     - -1
#                     - -1
#                     - 0
#                 - !!binary |
#                   AAAAAAAAAAA=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAAKEA=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAAAAA=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAADEA=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAAAAA=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAA4JKYHUA=
#           mesh_center:
#             - - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAAGEA=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAA/D8=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAA4JKYDUA=
#       - name: clown.facet
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/clown.facet
#         metadata:
#           dataset_type:
#             - PolyData
#           number_of_points:
#             - 631
#           number_of_cells:
#             - 802
#           number_of_arrays:
#             - 3
#           array_names:
#             - cell_data_array_names:
#                 - Material
#                 - PartNumber
#                 - RelativePartNumber
#           mesh_bounds:
#             - - -0.5
#               - 0.6949859857559204
#               - -0.4874640107154846
#               - 0.4874640107154846
#               - -1.090000033378601
#               - 0.5
#           mesh_center:
#             - - 0.0974929928779602
#               - 0.0
#               - -0.29500001668930054
#       - name: Box.glb
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/Box.glb
#         metadata:
#           dataset_type:
#             - MultiBlock
#           number_of_blocks:
#             - 1
#           mesh_bounds:
#             - - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAA4L8=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAA4D8=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAA4L8=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAA4D8=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAA4L8=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAA4D8=
#           mesh_center:
#             - - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAAAAA=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAAAAA=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAAAAA=
#       - name: elephav.obj
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/elephav.obj
#         metadata:
#           dataset_type:
#             - PolyData
#           number_of_points:
#             - 3444
#           number_of_cells:
#             - 1148
#           number_of_arrays:
#             - 2
#           array_names:
#             - cell_data_array_names:
#                 - GroupIds
#               point_data_array_names:
#                 - Normals
#           mesh_bounds:
#             - - -273.38336181640625
#               - 273.38336181640625
#               - 2.812407970428467
#               - 714.5693359375
#               - -417.7276916503906
#               - 717.3455810546875
#           mesh_center:
#             - - 0.0
#               - 358.69087195396423
#               - 149.80894470214844
#       - name: bun_zipper_res4.ply
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/bun_zipper_res4.ply
#         metadata:
#           dataset_type:
#             - PolyData
#           number_of_points:
#             - 453
#           number_of_cells:
#             - 948
#           mesh_bounds:
#             - - -0.09314659982919693
#               - 0.058159101754426956
#               - 0.03362039849162102
#               - 0.18189699947834015
#               - -0.056644000113010406
#               - 0.05780079960823059
#           mesh_center:
#             - - -0.017493749037384987
#               - 0.10775869898498058
#               - 0.0005783997476100922
#       - name: nut.slc
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/nut.slc
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 164492
#           number_of_cells:
#             - 155440
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - SLCImage
#           dimensions:
#             - - 68
#               - 41
#               - 59
#           spacing:
#             - - 1.0
#               - 1.0
#               - 1.0
#           mesh_bounds:
#             - - 0.0
#               - 67.0
#               - 0.0
#               - 40.0
#               - 0.0
#               - 58.0
#           mesh_center:
#             - - 33.5
#               - 20.0
#               - 29.0
#       - name: bolt.slc
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/bolt.slc
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 568260
#           number_of_cells:
#             - 547170
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - SLCImage
#           dimensions:
#             - - 70
#               - 123
#               - 66
#           spacing:
#             - - 1.0
#               - 1.0
#               - 1.0
#           mesh_bounds:
#             - - 0.0
#               - 69.0
#               - 0.0
#               - 122.0
#               - 0.0
#               - 65.0
#           mesh_center:
#             - - 34.5
#               - 61.0
#               - 32.5
#       - name: bunny.stl
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/bunny.stl
#         metadata:
#           dataset_type:
#             - PolyData
#           number_of_points:
#             - 56203
#           number_of_cells:
#             - 112402
#           mesh_bounds:
#             - - -23.550819396972656
#               - 84.19611358642578
#               - -42.00993728637695
#               - 45.791847229003906
#               - 5.27508544921875
#               - 113.16683959960938
#           mesh_center:
#             - - 30.322647094726562
#               - 1.8909549713134766
#               - 59.22096252441406
#   - name: vtk files
#     files:
#       - name: can-vtu.hdf
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/can-vtu.hdf
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 6724
#           number_of_cells:
#             - 4800
#           number_of_arrays:
#             - 16
#           array_names:
#             - cell_data_array_names:
#                 - EQPS
#               point_data_array_names:
#                 - ACCL
#                 - DISPL
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - VEL
#               field_data_array_names:
#                 - ElementBlockIds
#                 - Info_Records
#                 - KE
#                 - NSTEPS
#                 - QA_Records
#                 - TMSTEP
#                 - Title
#                 - XMOM
#                 - YMOM
#                 - ZMOM
#           mesh_bounds:
#             - - -12.16960620880127
#               - 6.002867221832275
#               - -3.600424289703369
#               - 5.562201976776123
#               - -18.33547592163086
#               - -13.456451416015625
#           mesh_center:
#             - - -3.083369493484497
#               - 0.980888843536377
#               - -15.895963668823242
#       - name: test.pvti
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/test.pvti
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 9261
#           number_of_cells:
#             - 8000
#           number_of_arrays:
#             - 2
#           array_names:
#             - cell_data_array_names:
#                 - myCellData
#               point_data_array_names:
#                 - myPointData
#           dimensions:
#             - - 21
#               - 21
#               - 21
#           spacing:
#             - - 0.5
#               - 1.0
#               - 1.0
#           mesh_bounds:
#             - - 0.0
#               - 10.0
#               - -10.0
#               - 10.0
#               - -10.0
#               - 10.0
#           mesh_center:
#             - - 5.0
#               - 0.0
#               - 0.0
#       - name: polyEx.pvtp
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/polyEx.pvtp
#         metadata:
#           dataset_type:
#             - PolyData
#           number_of_points:
#             - 8
#           number_of_cells:
#             - 6
#           number_of_arrays:
#             - 3
#           array_names:
#             - cell_data_array_names:
#                 - cell_scalars
#                 - cell_normals
#               point_data_array_names:
#                 - my_scalars
#           mesh_bounds:
#             - - 0.0
#               - 1.0
#               - 0.0
#               - 1.0
#               - 0.0
#               - 1.0
#           mesh_center:
#             - - 0.5
#               - 0.5
#               - 0.5
#       - name: pressure_20.pvtr
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/pressure_20.pvtr
#         metadata:
#           dataset_type:
#             - RectilinearGrid
#           number_of_points:
#             - 336
#           number_of_cells:
#             - 210
#           number_of_arrays:
#             - 3
#           array_names:
#             - cell_data_array_names:
#                 - vtkGhostTypes
#                 - pressure
#               field_data_array_names:
#                 - TimeValue
#           dimensions:
#             - - 8
#               - 7
#               - 6
#           mesh_bounds:
#             - - -1.0
#               - 6.0
#               - -1.0
#               - 5.0
#               - -1.0
#               - 4.0
#           mesh_center:
#             - - 2.5
#               - 2.0
#               - 1.5
#       - name: T0000000500.pvtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/T0000000500.pvtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 48823
#           number_of_cells:
#             - 39353
#           number_of_arrays:
#             - 5
#           array_names:
#             - cell_data_array_names:
#                 - density
#                 - velocity
#                 - shearstress
#               point_data_array_names:
#                 - node_value
#                 - simerr_type
#           mesh_bounds:
#             - - 53.0
#               - 121.0
#               - 50.0
#               - 97.0
#               - 64.0
#               - 182.0
#           mesh_center:
#             - - 87.0
#               - 73.5
#               - 123.0
#       - name: heart.vti
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/heart.vti
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 12288
#           number_of_cells:
#             - 10571
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - scalars
#           dimensions:
#             - - 32
#               - 32
#               - 12
#           spacing:
#             - - 1.0
#               - 1.0
#               - 4.0
#           mesh_bounds:
#             - - 0.0
#               - 31.0
#               - 0.0
#               - 31.0
#               - 0.0
#               - 44.0
#           mesh_center:
#             - - 15.5
#               - 15.5
#               - 22.0
#       - name: 0.vti
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/test/0.vti
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 4851
#           number_of_cells:
#             - 4000
#           number_of_arrays:
#             - 2
#           array_names:
#             - cell_data_array_names:
#                 - myCellData
#               point_data_array_names:
#                 - myPointData
#           dimensions:
#             - - 21
#               - 21
#               - 11
#           spacing:
#             - - 0.5
#               - 1.0
#               - 1.0
#           mesh_bounds:
#             - - 0.0
#               - 10.0
#               - -10.0
#               - 10.0
#               - -10.0
#               - 0.0
#           mesh_center:
#             - - 5.0
#               - 0.0
#               - -5.0
#       - name: 1.vti
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/test/1.vti
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 4851
#           number_of_cells:
#             - 4000
#           number_of_arrays:
#             - 2
#           array_names:
#             - cell_data_array_names:
#                 - myCellData
#               point_data_array_names:
#                 - myPointData
#           dimensions:
#             - - 21
#               - 21
#               - 11
#           spacing:
#             - - 0.5
#               - 1.0
#               - 1.0
#           mesh_bounds:
#             - - 0.0
#               - 10.0
#               - -10.0
#               - 10.0
#               - 0.0
#               - 10.0
#           mesh_center:
#             - - 5.0
#               - 0.0
#               - 5.0
#       - name: usa.vtk
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/usa.vtk
#         metadata:
#           dataset_type:
#             - PolyData
#           number_of_points:
#             - 3652
#           number_of_cells:
#             - 51
#           mesh_bounds:
#             - - -168.05299377441406
#               - -66.95249938964844
#               - 18.924999237060547
#               - 71.34249877929688
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - -117.50274658203125
#               - 45.13374900817871
#               - 0.0
#       - name: gh-935.vtk
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/gh-935.vtk
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 6
#           number_of_cells:
#             - 2
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - sol
#           mesh_bounds:
#             - - 0.0
#               - 1.0
#               - 0.0
#               - 1.0
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 0.5
#               - 0.5
#               - 0.0
#       - name: vox8_ascii.vtk
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/vox8_ascii.vtk
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 27
#           number_of_cells:
#             - 8
#           number_of_arrays:
#             - 12
#           array_names:
#             - cell_data_array_names:
#                 - scalars
#                 - cRamp1
#                 - cRamp2
#                 - cVects
#                 - cv2
#               point_data_array_names:
#                 - scalars
#                 - mytest
#                 - xRamp
#                 - yRamp
#                 - zRamp
#                 - outVect
#                 - vect2
#           mesh_bounds:
#             - - 0.0
#               - 2.0
#               - 0.0
#               - 2.0
#               - 0.0
#               - 2.0
#           mesh_center:
#             - - 1.0
#               - 1.0
#               - 1.0
#       - name: 02_structured.vtk
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/02_structured.vtk
#         metadata:
#           dataset_type:
#             - StructuredGrid
#           number_of_points:
#             - 147
#           number_of_cells:
#             - 72
#           number_of_arrays:
#             - 4
#           array_names:
#             - cell_data_array_names:
#                 - pressure1
#                 - pressure2
#               point_data_array_names:
#                 - temp1
#                 - temp2
#           dimensions:
#             - - 7
#               - 7
#               - 3
#           mesh_bounds:
#             - - -0.015338152602
#               - 1.0147581381
#               - -0.015274787969
#               - 1.0157021684
#               - -0.046818381932
#               - 1.0495865001
#           mesh_center:
#             - - 0.49970999274899996
#               - 0.5002136902155
#               - 0.501384059084
#       - name: vox8_binary.vtk
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/vox8_binary.vtk
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 27
#           number_of_cells:
#             - 8
#           number_of_arrays:
#             - 12
#           array_names:
#             - cell_data_array_names:
#                 - scalars
#                 - cRamp1
#                 - cRamp2
#                 - cVects
#                 - cv2
#               point_data_array_names:
#                 - scalars
#                 - mytest
#                 - xRamp
#                 - yRamp
#                 - zRamp
#                 - outVect
#                 - vect2
#           mesh_bounds:
#             - - 0.0
#               - 2.0
#               - 0.0
#               - 2.0
#               - 0.0
#               - 2.0
#           mesh_center:
#             - - 1.0
#               - 1.0
#               - 1.0
#       - name: 01_image.vtk
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/01_image.vtk
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 147
#           number_of_cells:
#             - 72
#           number_of_arrays:
#             - 4
#           array_names:
#             - cell_data_array_names:
#                 - pressure1
#                 - pressure2
#               point_data_array_names:
#                 - temp1
#                 - temp2
#           dimensions:
#             - - 7
#               - 7
#               - 3
#           spacing:
#             - - 1.0
#               - 1.0
#               - 1.0
#           mesh_bounds:
#             - - 0.0
#               - 6.0
#               - 0.0
#               - 6.0
#               - 0.0
#               - 2.0
#           mesh_center:
#             - - 3.0
#               - 3.0
#               - 1.0
#       - name: 06_color_scalars.vtk
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/06_color_scalars.vtk
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 5
#           number_of_cells:
#             - 2
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - lut
#           mesh_bounds:
#             - - -1.5
#               - 1.5
#               - -1.5
#               - 1.5
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 0.0
#               - 0.0
#               - 0.0
#       - name: hello.vtk
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/hello.vtk
#         metadata:
#           dataset_type:
#             - PolyData
#           number_of_points:
#             - 22
#           number_of_cells:
#             - 15
#           number_of_lines:
#             - 15
#           mesh_bounds:
#             - - 0.0
#               - 9.0
#               - 0.0
#               - 2.0
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 4.5
#               - 1.0
#               - 0.0
#       - name: 04_rectilinear.vtk
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/04_rectilinear.vtk
#         metadata:
#           dataset_type:
#             - RectilinearGrid
#           number_of_points:
#             - 40
#           number_of_cells:
#             - 27
#           number_of_arrays:
#             - 4
#           array_names:
#             - cell_data_array_names:
#                 - pressure1
#                 - pressure2
#               point_data_array_names:
#                 - temp1
#                 - temp2
#           dimensions:
#             - - 10
#               - 4
#               - 1
#           mesh_bounds:
#             - - 0.0
#               - 1.0
#               - 0.0
#               - 2.0
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 0.5
#               - 1.0
#               - 0.0
#       - name: 06_unstructured.vtk
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/06_unstructured.vtk
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 42
#           number_of_cells:
#             - 12
#           number_of_arrays:
#             - 2
#           array_names:
#             - cell_data_array_names:
#                 - mat_id
#               point_data_array_names:
#                 - node_groups
#           mesh_bounds:
#             - - 1.2999999523162842
#               - 1.5
#               - 0.800000011920929
#               - 1.0
#               - 0.0
#               - 0.5
#           mesh_center:
#             - - 1.399999976158142
#               - 0.9000000059604645
#               - 0.25
#       - name: polyEx0.vtp
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/polyEx0.vtp
#         metadata:
#           dataset_type:
#             - PolyData
#           number_of_points:
#             - 8
#           number_of_cells:
#             - 6
#           number_of_arrays:
#             - 3
#           array_names:
#             - cell_data_array_names:
#                 - cell_scalars
#                 - cell_normals
#               point_data_array_names:
#                 - my_scalars
#           mesh_bounds:
#             - - 0.0
#               - 1.0
#               - 0.0
#               - 1.0
#               - 0.0
#               - 1.0
#           mesh_center:
#             - - 0.5
#               - 0.5
#               - 0.5
#       - name: Bunny.vtp
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/Bunny.vtp
#         metadata:
#           dataset_type:
#             - PolyData
#           number_of_points:
#             - 872
#           number_of_cells:
#             - 1502
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - Normals
#           mesh_bounds:
#             - - -0.13155962526798248
#               - 0.18016336858272552
#               - -0.12048563361167908
#               - 0.18769524991512299
#               - -0.14300920069217682
#               - 0.09850578755140305
#           mesh_center:
#             - - 0.02430187165737152
#               - 0.033604808151721954
#               - -0.022251706570386887
#       - name: RectilinearGrid.vtr
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/RectilinearGrid.vtr
#         metadata:
#           dataset_type:
#             - RectilinearGrid
#           number_of_points:
#             - 545025
#           number_of_cells:
#             - 524288
#           number_of_arrays:
#             - 9
#           array_names:
#             - cell_data_array_names:
#                 - Pressure
#                 - Void Volume Fraction
#                 - X Velocity
#                 - Y Velocity
#                 - Z Velocity
#                 - Volume Fraction for Armor Plate
#                 - Mass for Armor Plate
#                 - Volume Fraction for Body, Nose
#                 - Mass for Body, Nose
#           dimensions:
#             - - 129
#               - 65
#               - 65
#           mesh_bounds:
#             - - -7.5
#               - 4.0
#               - -3.0
#               - 3.0
#               - -3.0
#               - 3.0
#           mesh_center:
#             - - -1.75
#               - 0.0
#               - 0.0
#       - name: pressure_20_1.vtr
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/pressure_20/pressure_20_1.vtr
#         metadata:
#           dataset_type:
#             - RectilinearGrid
#           number_of_points:
#             - 210
#           number_of_cells:
#             - 120
#           number_of_arrays:
#             - 3
#           array_names:
#             - cell_data_array_names:
#                 - vtkGhostTypes
#                 - pressure
#               field_data_array_names:
#                 - TimeValue
#           dimensions:
#             - - 5
#               - 7
#               - 6
#           mesh_bounds:
#             - - 2.0
#               - 6.0
#               - -1.0
#               - 5.0
#               - -1.0
#               - 4.0
#           mesh_center:
#             - - 4.0
#               - 2.0
#               - 1.5
#       - name: pressure_20_0.vtr
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/pressure_20/pressure_20_0.vtr
#         metadata:
#           dataset_type:
#             - RectilinearGrid
#           number_of_points:
#             - 252
#           number_of_cells:
#             - 150
#           number_of_arrays:
#             - 3
#           array_names:
#             - cell_data_array_names:
#                 - vtkGhostTypes
#                 - pressure
#               field_data_array_names:
#                 - TimeValue
#           dimensions:
#             - - 6
#               - 7
#               - 6
#           mesh_bounds:
#             - - -1.0
#               - 4.0
#               - -1.0
#               - 5.0
#               - -1.0
#               - 4.0
#           mesh_center:
#             - - 1.5
#               - 2.0
#               - 1.5
#       - name: StructuredGrid.vts
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/StructuredGrid.vts
#         metadata:
#           dataset_type:
#             - StructuredGrid
#           number_of_points:
#             - 648
#           number_of_cells:
#             - 440
#           number_of_arrays:
#             - 3
#           array_names:
#             - point_data_array_names:
#                 - Density
#                 - Momentum
#                 - StagnationEnergy
#           dimensions:
#             - - 6
#               - 12
#               - 9
#           mesh_bounds:
#             - - 0.0
#               - 6.365341663360596
#               - -5.144453048706055
#               - 5.144453048706055
#               - 23.37380027770996
#               - 32.894798278808594
#           mesh_center:
#             - - 3.182670831680298
#               - 0.0
#               - 28.134299278259277
#       - name: vox8_binary_inline_zlib.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/vox8_binary_inline_zlib.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 27
#           number_of_cells:
#             - 8
#           number_of_arrays:
#             - 12
#           array_names:
#             - cell_data_array_names:
#                 - scalars
#                 - cRamp1
#                 - cRamp2
#                 - cVects
#                 - cv2
#               point_data_array_names:
#                 - scalars
#                 - mytest
#                 - xRamp
#                 - yRamp
#                 - zRamp
#                 - outVect
#                 - vect2
#           mesh_bounds:
#             - - 0.0
#               - 2.0
#               - 0.0
#               - 2.0
#               - 0.0
#               - 2.0
#           mesh_center:
#             - - 1.0
#               - 1.0
#               - 1.0
#       - name: ugridex.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ugridex.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 27
#           number_of_cells:
#             - 12
#           number_of_arrays:
#             - 2
#           array_names:
#             - cell_data_array_names:
#                 - nmax
#               point_data_array_names:
#                 - csum
#           mesh_bounds:
#             - - 0.0
#               - 2.0
#               - 0.0
#               - 1.0
#               - 0.0
#               - 6.0
#           mesh_center:
#             - - 1.0
#               - 0.5
#               - 3.0
#       - name: 01_raw_binary_int64.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/01_raw_binary_int64.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 64
#           number_of_cells:
#             - 162
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - m
#           mesh_bounds:
#             - - 0.0
#               - 1.0
#               - 0.0
#               - 1.0
#               - 0.0
#               - 1.0
#           mesh_center:
#             - - 0.5
#               - 0.5
#               - 0.5
#       - name: test_mesh.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/test_mesh.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 7
#           number_of_cells:
#             - 5
#           number_of_arrays:
#             - 4
#           array_names:
#             - cell_data_array_names:
#                 - cell_index
#                 - cell_func_values
#               point_data_array_names:
#                 - point_index
#                 - function
#           mesh_bounds:
#             - - 0.0
#               - 2.0
#               - 0.0
#               - 1.0
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 1.0
#               - 0.5
#               - 0.0
#       - name: fire_ug.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/fire_ug.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 12323
#           number_of_cells:
#             - 10462
#           number_of_arrays:
#             - 6
#           array_names:
#             - point_data_array_names:
#                 - t
#                 - uvw
#                 - u
#                 - v
#                 - w
#                 - mfrac
#           mesh_bounds:
#             - - 0.0
#               - 6.0
#               - 0.0
#               - 2.5
#               - 0.0
#               - 2.3999998569488525
#           mesh_center:
#             - - 3.0
#               - 1.25
#               - 1.1999999284744263
#       - name: 02_raw_compressed.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/02_raw_compressed.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 64
#           number_of_cells:
#             - 162
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - m
#           mesh_bounds:
#             - - 0.0
#               - 1.0
#               - 0.0
#               - 1.0
#               - 0.0
#               - 1.0
#           mesh_center:
#             - - 0.5
#               - 0.5
#               - 0.5
#       - name: vox8_binary_inline.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/vox8_binary_inline.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 27
#           number_of_cells:
#             - 8
#           number_of_arrays:
#             - 12
#           array_names:
#             - cell_data_array_names:
#                 - scalars
#                 - cRamp1
#                 - cRamp2
#                 - cVects
#                 - cv2
#               point_data_array_names:
#                 - scalars
#                 - mytest
#                 - xRamp
#                 - yRamp
#                 - zRamp
#                 - outVect
#                 - vect2
#           mesh_bounds:
#             - - 0.0
#               - 2.0
#               - 0.0
#               - 2.0
#               - 0.0
#               - 2.0
#           mesh_center:
#             - - 1.0
#               - 1.0
#               - 1.0
#       - name: vox8_ascii.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/vox8_ascii.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 27
#           number_of_cells:
#             - 8
#           number_of_arrays:
#             - 12
#           array_names:
#             - cell_data_array_names:
#                 - scalars
#                 - cRamp1
#                 - cRamp2
#                 - cVects
#                 - cv2
#               point_data_array_names:
#                 - scalars
#                 - mytest
#                 - xRamp
#                 - yRamp
#                 - zRamp
#                 - outVect
#                 - vect2
#           mesh_bounds:
#             - - 0.0
#               - 2.0
#               - 0.0
#               - 2.0
#               - 0.0
#               - 2.0
#           mesh_center:
#             - - 1.0
#               - 1.0
#               - 1.0
#       - name: 00_raw_binary.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/00_raw_binary.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 64
#           number_of_cells:
#             - 162
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - m
#           mesh_bounds:
#             - - 0.0
#               - 1.0
#               - 0.0
#               - 1.0
#               - 0.0
#               - 1.0
#           mesh_center:
#             - - 0.5
#               - 0.5
#               - 0.5
#       - name: vox8_binary_appended.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/vox8_binary_appended.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 27
# ...
#               - -12.0
#               - -0.3924649953842163
#               - -5.200829982757568
#               - 2.5329198837280273
#           mesh_center:
#             - - 3.3689398765563965
#               - -6.196232497692108
#               - -1.3339550495147705
#       - name: ex-blow_5_0_1.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_0_1.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 81
#           number_of_cells:
#             - 116
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 6.737879753112793
#               - -12.0
#               - -0.3947420120239258
#               - 1.02961003780365
#               - 7.254090309143066
#           mesh_center:
#             - - 3.3689398765563965
#               - -6.197371006011963
#               - 4.141850173473358
#       - name: ex-blow_5_0_7.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_0_7.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 80
#           number_of_cells:
#             - 116
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 6.710299968719482
#               - 24.272518157958984
#               - 36.0
#               - 0.007290000095963478
#               - 6.137589931488037
#           mesh_center:
#             - - 3.355149984359741
#               - 30.136259078979492
#               - 3.0724399657920003
#       - name: ex-blow_5_1_6.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_1_6.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 37
#           number_of_cells:
#             - 15
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 7.0
#               - 0.0
#               - 24.0
#               - -3.8499999046325684
#               - 6.019000053405762
#           mesh_center:
#             - - 3.5
#               - 12.0
#               - 1.0845000743865967
#       - name: ex-blow_5_0_5.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_0_5.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 96
#           number_of_cells:
#             - 116
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 6.530529975891113
#               - 23.30864906311035
#               - 24.826541900634766
#               - -3.6537070274353027
#               - 3.6471240520477295
#           mesh_center:
#             - - 3.2652649879455566
#               - 24.06759548187256
#               - -0.003291487693786621
#       - name: ex-blow_5_1_1.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_1_1.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 28
#           number_of_cells:
#             - 16
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 5.0
#               - 5.0
#               - 7.442180156707764
#               - 7.934120178222656
#               - 5.243100166320801
#               - 6.529600143432617
#           mesh_center:
#             - - 5.0
#               - 7.68815016746521
#               - 5.886350154876709
#       - name: ex-blow_5_1_5.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_1_5.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 42
#           number_of_cells:
#             - 21
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 5.0
#               - 5.0
#               - 7.743239879608154
#               - 8.157979965209961
#               - 5.0
#               - 7.684000015258789
#           mesh_center:
#             - - 5.0
#               - 7.950609922409058
#               - 6.3420000076293945
#       - name: ex-blow_5_0_6.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_0_6.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 81
#           number_of_cells:
#             - 116
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 6.710299968719482
#               - 24.16718101501465
#               - 36.0
#               - -5.999469757080078
#               - 0.9110809564590454
#           mesh_center:
#             - - 3.355149984359741
#               - 30.083590507507324
#               - -2.5441944003105164
#       - name: ex-blow_5_1_7.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_1_7.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 33
#           number_of_cells:
#             - 17
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 7.0
#               - 11.25
#               - 26.0
#               - -3.8499999046325684
#               - 6.0
#           mesh_center:
#             - - 3.5
#               - 18.625
#               - 1.0750000476837158
#       - name: ex-blow_5_1_4.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_1_4.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 21
#           number_of_cells:
#             - 11
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 5.0
#               - 7.853549957275391
#               - 8.154339790344238
#               - 6.019000053405762
#               - 7.853599548339844
#           mesh_center:
#             - - 2.5
#               - 8.003944873809814
#               - 6.936299800872803
#       - name: ex-blow_5_1_3.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_1_3.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 34
#           number_of_cells:
#             - 17
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 5.0
#               - 7.449429988861084
#               - 7.964890003204346
#               - 6.387399673461914
#               - 8.0
#           mesh_center:
#             - - 2.5
#               - 7.707159996032715
#               - 7.193699836730957
#       - name: ex-blow_5_0_4.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_0_4.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 83
#           number_of_cells:
#             - 116
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 7.161890029907227
#               - 11.430950164794922
#               - 23.945070266723633
#               - -3.8500001430511475
#               - 6.0
#           mesh_center:
#             - - 3.5809450149536133
#               - 17.688010215759277
#               - 1.0749999284744263
#       - name: ex-blow_5_1_0.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_1_0.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 39
#           number_of_cells:
#             - 17
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 7.0
#               - -2.0
#               - 8.0
#               - -3.8499999046325684
#               - 6.393500328063965
#           mesh_center:
#             - - 3.5
#               - 3.0
#               - 1.2717502117156982
#       - name: ex-blow_5_1_2.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_1_2.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 29
#           number_of_cells:
#             - 15
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 5.0
#               - 0.0
#               - 7.6915998458862305
#               - 5.0
#               - 8.0
#           mesh_center:
#             - - 2.5
#               - 3.8457999229431152
#               - 6.5
#       - name: ex-blow_5_0_3.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_0_3.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 83
#           number_of_cells:
#             - 116
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 7.161890029907227
#               - -0.020428001880645752
#               - 12.578660011291504
#               - -3.8499999046325684
#               - 7.494060039520264
#           mesh_center:
#             - - 3.5809450149536133
#               - 6.279116004705429
#               - 1.8220300674438477
#       - name: ex-blow_5_0_2.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_0_2.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 96
#           number_of_cells:
#             - 116
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 6.588759899139404
#               - -1.045849084854126
#               - 0.46295398473739624
#               - -1.8193100690841675
#               - 5.744719982147217
#           mesh_center:
#             - - 3.294379949569702
#               - -0.29144755005836487
#               - 1.9627049565315247
# __source__:
#   root: SuperGroup

# %%
! python3 /home/sarbani/harvester-curator/darus_data_harvester/harvester/harvester.py --path /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder
# Out:
# ---*** Metadata Harvester Output ***---
#
# Output will be written to: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/harvester_output/harvester_output.json
# /home/sarbani/.local/lib/python3.10/site-packages/sdRDM/base/datamodel.py:249: UserWarning: No 'URL' and 'Commit' specified. This model might not be re-usable.
#   warnings.warn(
# name: all parsed file groups
# file_group_names:
#   2D image files:
#     - bmp
#     - img
#     - jpg
#     - pgm
#     - png
#     - pnm
#     - ppm
#     - tif
#   3D image files:
#     - dcm
#     - dem
#     - exo
#     - facet
#     - glb
#     - obj
#     - ply
#     - slc
#     - stl
#   vtk files:
#     - hdf
#     - pvti
#     - pvtp
#     - pvtr
#     - pvtu
#     - vti
#     - vtk
#     - vtp
#     - vtr
#     - vts
#     - vtu
# groups:
#   - name: 2D image files
#     files:
#       - name: masonry.bmp
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/masonry.bmp
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 65536
#           number_of_cells:
#             - 65025
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - BMPImage
#           dimensions:
#             - - 256
#               - 256
#               - 1
#           spacing:
#             - - 1.0
#               - 1.0
#               - 1.0
#           mesh_bounds:
#             - - 0.0
#               - 255.0
#               - 0.0
#               - 255.0
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 127.5
#               - 127.5
#               - 0.0
#       - name: prostate.img
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/prostate.img
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 262144
#           number_of_cells:
#             - 261121
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - DICOMImage
#           dimensions:
#             - - 512
#               - 512
#               - 1
#           spacing:
#             - - 0.9375
#               - 0.9375
#               - 5.0
#           mesh_bounds:
#             - - 0.0
#               - 479.0625
#               - 0.0
#               - 479.0625
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 239.53125
#               - 239.53125
#               - 0.0
#       - name: earth.jpg
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/earth.jpg
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 2097152
#           number_of_cells:
#             - 2094081
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - JPEGImage
#           dimensions:
#             - - 2048
#               - 1024
#               - 1
#           spacing:
#             - - 1.0
#               - 1.0
#               - 1.0
#           mesh_bounds:
#             - - 0.0
#               - 2047.0
#               - 0.0
#               - 1023.0
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 1023.5
#               - 511.5
#               - 0.0
#       - name: binary.pgm
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/binary.pgm
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 254660
#           number_of_cells:
#             - 253638
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - ImageFile
#           dimensions:
#             - - 595
#               - 428
#               - 1
#           spacing:
#             - - 1.0
#               - 1.0
#               - 1.0
#           mesh_bounds:
#             - - 0.0
#               - 594.0
#               - 0.0
#               - 427.0
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 297.0
#               - 213.5
#               - 0.0
#       - name: uni_stuttgart.png
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/uni_stuttgart.png
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 58080
#           number_of_cells:
#             - 57509
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - PNGImage
#           dimensions:
#             - - 440
#               - 132
#               - 1
#           spacing:
#             - - 1.0
#               - 1.0
#               - 1.0
#           mesh_bounds:
#             - - 0.0
#               - 439.0
#               - 0.0
#               - 131.0
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 219.5
#               - 65.5
#               - 0.0
#       - name: Gourds.pnm
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/Gourds.pnm
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 307200
#           number_of_cells:
#             - 306081
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - ImageFile
#           dimensions:
#             - - 640
#               - 480
#               - 1
#           spacing:
#             - - 1.0
#               - 1.0
#               - 1.0
#           mesh_bounds:
#             - - 0.0
#               - 639.0
#               - 0.0
#               - 479.0
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 319.5
#               - 239.5
#               - 0.0
#       - name: earth.ppm
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/earth.ppm
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 131072
#           number_of_cells:
#             - 130305
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - ImageFile
#           dimensions:
#             - - 512
#               - 256
#               - 1
#           spacing:
#             - - 1.0
#               - 1.0
#               - 1.0
#           mesh_bounds:
#             - - 0.0
#               - 511.0
#               - 0.0
#               - 255.0
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 255.5
#               - 127.5
#               - 0.0
#       - name: ColorCells.tif
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ColorCells.tif
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 90000
#           number_of_cells:
#             - 89401
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - Tiff Scalars
#           dimensions:
#             - - 300
#               - 300
#               - 1
#           spacing:
#             - - 0.35277777777777775
#               - 0.35277777777777775
#               - 0.35277777777777775
#           mesh_bounds:
#             - - 0.0
#               - 105.48055555555554
#               - 0.0
#               - 105.48055555555554
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 52.74027777777777
#               - 52.74027777777777
#               - 0.0
#   - name: 3D image files
#     files:
#       - name: DICOM_KNEE.dcm
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/DICOM_KNEE.dcm
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 262144
#           number_of_cells:
#             - 261121
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - DICOMImage
#           dimensions:
#             - - 512
#               - 512
#               - 1
#           spacing:
#             - - 0.42969998717308044
#               - 0.42969998717308044
#               - 0.800000011920929
#           mesh_bounds:
#             - - 0.0
#               - 219.5766934454441
#               - 0.0
#               - 219.5766934454441
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 109.78834672272205
#               - 109.78834672272205
#               - 0.0
#       - name: SainteHelens.dem
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/SainteHelens.dem
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 152709
#           number_of_cells:
#             - 151916
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - Elevation
#           dimensions:
#             - - 327
#               - 467
#               - 1
#           spacing:
#             - - 30.0
#               - 30.0
#               - 1.0
#           mesh_bounds:
#             - - 557945.0
#               - 567725.0
#               - 5107991.5
#               - 5121971.5
#               - 682.0
#               - 682.0
#           mesh_center:
#             - - 562835.0
#               - 5114981.5
#               - 682.0
#       - name: mesh_fs8.exo
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/mesh_fs8.exo
#         metadata:
#           dataset_type:
#             - MultiBlock
#           number_of_blocks:
#             - 8
#           mesh_bounds:
#             - - !!python/object/apply:numpy.core.multiarray.scalar
#                 - &id001 !!python/object/apply:numpy.dtype
#                   args:
#                     - f8
#                     - false
#                     - true
#                   state: !!python/tuple
#                     - 3
#                     - <
#                     - null
#                     - null
#                     - null
#                     - -1
#                     - -1
#                     - 0
#                 - !!binary |
#                   AAAAAAAAAAA=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAAKEA=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAAAAA=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAADEA=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAAAAA=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAA4JKYHUA=
#           mesh_center:
#             - - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAAGEA=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAA/D8=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAA4JKYDUA=
#       - name: clown.facet
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/clown.facet
#         metadata:
#           dataset_type:
#             - PolyData
#           number_of_points:
#             - 631
#           number_of_cells:
#             - 802
#           number_of_arrays:
#             - 3
#           array_names:
#             - cell_data_array_names:
#                 - Material
#                 - PartNumber
#                 - RelativePartNumber
#           mesh_bounds:
#             - - -0.5
#               - 0.6949859857559204
#               - -0.4874640107154846
#               - 0.4874640107154846
#               - -1.090000033378601
#               - 0.5
#           mesh_center:
#             - - 0.0974929928779602
#               - 0.0
#               - -0.29500001668930054
#       - name: Box.glb
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/Box.glb
#         metadata:
#           dataset_type:
#             - MultiBlock
#           number_of_blocks:
#             - 1
#           mesh_bounds:
#             - - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAA4L8=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAA4D8=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAA4L8=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAA4D8=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAA4L8=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAA4D8=
#           mesh_center:
#             - - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAAAAA=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAAAAA=
#               - !!python/object/apply:numpy.core.multiarray.scalar
#                 - *id001
#                 - !!binary |
#                   AAAAAAAAAAA=
#       - name: elephav.obj
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/elephav.obj
#         metadata:
#           dataset_type:
#             - PolyData
#           number_of_points:
#             - 3444
#           number_of_cells:
#             - 1148
#           number_of_arrays:
#             - 2
#           array_names:
#             - cell_data_array_names:
#                 - GroupIds
#               point_data_array_names:
#                 - Normals
#           mesh_bounds:
#             - - -273.38336181640625
#               - 273.38336181640625
#               - 2.812407970428467
#               - 714.5693359375
#               - -417.7276916503906
#               - 717.3455810546875
#           mesh_center:
#             - - 0.0
#               - 358.69087195396423
#               - 149.80894470214844
#       - name: bun_zipper_res4.ply
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/bun_zipper_res4.ply
#         metadata:
#           dataset_type:
#             - PolyData
#           number_of_points:
#             - 453
#           number_of_cells:
#             - 948
#           mesh_bounds:
#             - - -0.09314659982919693
#               - 0.058159101754426956
#               - 0.03362039849162102
#               - 0.18189699947834015
#               - -0.056644000113010406
#               - 0.05780079960823059
#           mesh_center:
#             - - -0.017493749037384987
#               - 0.10775869898498058
#               - 0.0005783997476100922
#       - name: nut.slc
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/nut.slc
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 164492
#           number_of_cells:
#             - 155440
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - SLCImage
#           dimensions:
#             - - 68
#               - 41
#               - 59
#           spacing:
#             - - 1.0
#               - 1.0
#               - 1.0
#           mesh_bounds:
#             - - 0.0
#               - 67.0
#               - 0.0
#               - 40.0
#               - 0.0
#               - 58.0
#           mesh_center:
#             - - 33.5
#               - 20.0
#               - 29.0
#       - name: bolt.slc
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/bolt.slc
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 568260
#           number_of_cells:
#             - 547170
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - SLCImage
#           dimensions:
#             - - 70
#               - 123
#               - 66
#           spacing:
#             - - 1.0
#               - 1.0
#               - 1.0
#           mesh_bounds:
#             - - 0.0
#               - 69.0
#               - 0.0
#               - 122.0
#               - 0.0
#               - 65.0
#           mesh_center:
#             - - 34.5
#               - 61.0
#               - 32.5
#       - name: bunny.stl
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/bunny.stl
#         metadata:
#           dataset_type:
#             - PolyData
#           number_of_points:
#             - 56203
#           number_of_cells:
#             - 112402
#           mesh_bounds:
#             - - -23.550819396972656
#               - 84.19611358642578
#               - -42.00993728637695
#               - 45.791847229003906
#               - 5.27508544921875
#               - 113.16683959960938
#           mesh_center:
#             - - 30.322647094726562
#               - 1.8909549713134766
#               - 59.22096252441406
#   - name: vtk files
#     files:
#       - name: can-vtu.hdf
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/can-vtu.hdf
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 6724
#           number_of_cells:
#             - 4800
#           number_of_arrays:
#             - 16
#           array_names:
#             - cell_data_array_names:
#                 - EQPS
#               point_data_array_names:
#                 - ACCL
#                 - DISPL
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - VEL
#               field_data_array_names:
#                 - ElementBlockIds
#                 - Info_Records
#                 - KE
#                 - NSTEPS
#                 - QA_Records
#                 - TMSTEP
#                 - Title
#                 - XMOM
#                 - YMOM
#                 - ZMOM
#           mesh_bounds:
#             - - -12.16960620880127
#               - 6.002867221832275
#               - -3.600424289703369
#               - 5.562201976776123
#               - -18.33547592163086
#               - -13.456451416015625
#           mesh_center:
#             - - -3.083369493484497
#               - 0.980888843536377
#               - -15.895963668823242
#       - name: test.pvti
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/test.pvti
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 9261
#           number_of_cells:
#             - 8000
#           number_of_arrays:
#             - 2
#           array_names:
#             - cell_data_array_names:
#                 - myCellData
#               point_data_array_names:
#                 - myPointData
#           dimensions:
#             - - 21
#               - 21
#               - 21
#           spacing:
#             - - 0.5
#               - 1.0
#               - 1.0
#           mesh_bounds:
#             - - 0.0
#               - 10.0
#               - -10.0
#               - 10.0
#               - -10.0
#               - 10.0
#           mesh_center:
#             - - 5.0
#               - 0.0
#               - 0.0
#       - name: polyEx.pvtp
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/polyEx.pvtp
#         metadata:
#           dataset_type:
#             - PolyData
#           number_of_points:
#             - 8
#           number_of_cells:
#             - 6
#           number_of_arrays:
#             - 3
#           array_names:
#             - cell_data_array_names:
#                 - cell_scalars
#                 - cell_normals
#               point_data_array_names:
#                 - my_scalars
#           mesh_bounds:
#             - - 0.0
#               - 1.0
#               - 0.0
#               - 1.0
#               - 0.0
#               - 1.0
#           mesh_center:
#             - - 0.5
#               - 0.5
#               - 0.5
#       - name: pressure_20.pvtr
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/pressure_20.pvtr
#         metadata:
#           dataset_type:
#             - RectilinearGrid
#           number_of_points:
#             - 336
#           number_of_cells:
#             - 210
#           number_of_arrays:
#             - 3
#           array_names:
#             - cell_data_array_names:
#                 - vtkGhostTypes
#                 - pressure
#               field_data_array_names:
#                 - TimeValue
#           dimensions:
#             - - 8
#               - 7
#               - 6
#           mesh_bounds:
#             - - -1.0
#               - 6.0
#               - -1.0
#               - 5.0
#               - -1.0
#               - 4.0
#           mesh_center:
#             - - 2.5
#               - 2.0
#               - 1.5
#       - name: T0000000500.pvtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/T0000000500.pvtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 48823
#           number_of_cells:
#             - 39353
#           number_of_arrays:
#             - 5
#           array_names:
#             - cell_data_array_names:
#                 - density
#                 - velocity
#                 - shearstress
#               point_data_array_names:
#                 - node_value
#                 - simerr_type
#           mesh_bounds:
#             - - 53.0
#               - 121.0
#               - 50.0
#               - 97.0
#               - 64.0
#               - 182.0
#           mesh_center:
#             - - 87.0
#               - 73.5
#               - 123.0
#       - name: heart.vti
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/heart.vti
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 12288
#           number_of_cells:
#             - 10571
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - scalars
#           dimensions:
#             - - 32
#               - 32
#               - 12
#           spacing:
#             - - 1.0
#               - 1.0
#               - 4.0
#           mesh_bounds:
#             - - 0.0
#               - 31.0
#               - 0.0
#               - 31.0
#               - 0.0
#               - 44.0
#           mesh_center:
#             - - 15.5
#               - 15.5
#               - 22.0
#       - name: 0.vti
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/test/0.vti
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 4851
#           number_of_cells:
#             - 4000
#           number_of_arrays:
#             - 2
#           array_names:
#             - cell_data_array_names:
#                 - myCellData
#               point_data_array_names:
#                 - myPointData
#           dimensions:
#             - - 21
#               - 21
#               - 11
#           spacing:
#             - - 0.5
#               - 1.0
#               - 1.0
#           mesh_bounds:
#             - - 0.0
#               - 10.0
#               - -10.0
#               - 10.0
#               - -10.0
#               - 0.0
#           mesh_center:
#             - - 5.0
#               - 0.0
#               - -5.0
#       - name: 1.vti
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/test/1.vti
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 4851
#           number_of_cells:
#             - 4000
#           number_of_arrays:
#             - 2
#           array_names:
#             - cell_data_array_names:
#                 - myCellData
#               point_data_array_names:
#                 - myPointData
#           dimensions:
#             - - 21
#               - 21
#               - 11
#           spacing:
#             - - 0.5
#               - 1.0
#               - 1.0
#           mesh_bounds:
#             - - 0.0
#               - 10.0
#               - -10.0
#               - 10.0
#               - 0.0
#               - 10.0
#           mesh_center:
#             - - 5.0
#               - 0.0
#               - 5.0
#       - name: usa.vtk
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/usa.vtk
#         metadata:
#           dataset_type:
#             - PolyData
#           number_of_points:
#             - 3652
#           number_of_cells:
#             - 51
#           mesh_bounds:
#             - - -168.05299377441406
#               - -66.95249938964844
#               - 18.924999237060547
#               - 71.34249877929688
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - -117.50274658203125
#               - 45.13374900817871
#               - 0.0
#       - name: gh-935.vtk
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/gh-935.vtk
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 6
#           number_of_cells:
#             - 2
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - sol
#           mesh_bounds:
#             - - 0.0
#               - 1.0
#               - 0.0
#               - 1.0
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 0.5
#               - 0.5
#               - 0.0
#       - name: vox8_ascii.vtk
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/vox8_ascii.vtk
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 27
#           number_of_cells:
#             - 8
#           number_of_arrays:
#             - 12
#           array_names:
#             - cell_data_array_names:
#                 - scalars
#                 - cRamp1
#                 - cRamp2
#                 - cVects
#                 - cv2
#               point_data_array_names:
#                 - scalars
#                 - mytest
#                 - xRamp
#                 - yRamp
#                 - zRamp
#                 - outVect
#                 - vect2
#           mesh_bounds:
#             - - 0.0
#               - 2.0
#               - 0.0
#               - 2.0
#               - 0.0
#               - 2.0
#           mesh_center:
#             - - 1.0
#               - 1.0
#               - 1.0
#       - name: 02_structured.vtk
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/02_structured.vtk
#         metadata:
#           dataset_type:
#             - StructuredGrid
#           number_of_points:
#             - 147
#           number_of_cells:
#             - 72
#           number_of_arrays:
#             - 4
#           array_names:
#             - cell_data_array_names:
#                 - pressure1
#                 - pressure2
#               point_data_array_names:
#                 - temp1
#                 - temp2
#           dimensions:
#             - - 7
#               - 7
#               - 3
#           mesh_bounds:
#             - - -0.015338152602
#               - 1.0147581381
#               - -0.015274787969
#               - 1.0157021684
#               - -0.046818381932
#               - 1.0495865001
#           mesh_center:
#             - - 0.49970999274899996
#               - 0.5002136902155
#               - 0.501384059084
#       - name: vox8_binary.vtk
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/vox8_binary.vtk
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 27
#           number_of_cells:
#             - 8
#           number_of_arrays:
#             - 12
#           array_names:
#             - cell_data_array_names:
#                 - scalars
#                 - cRamp1
#                 - cRamp2
#                 - cVects
#                 - cv2
#               point_data_array_names:
#                 - scalars
#                 - mytest
#                 - xRamp
#                 - yRamp
#                 - zRamp
#                 - outVect
#                 - vect2
#           mesh_bounds:
#             - - 0.0
#               - 2.0
#               - 0.0
#               - 2.0
#               - 0.0
#               - 2.0
#           mesh_center:
#             - - 1.0
#               - 1.0
#               - 1.0
#       - name: 01_image.vtk
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/01_image.vtk
#         metadata:
#           dataset_type:
#             - ImageData
#           number_of_points:
#             - 147
#           number_of_cells:
#             - 72
#           number_of_arrays:
#             - 4
#           array_names:
#             - cell_data_array_names:
#                 - pressure1
#                 - pressure2
#               point_data_array_names:
#                 - temp1
#                 - temp2
#           dimensions:
#             - - 7
#               - 7
#               - 3
#           spacing:
#             - - 1.0
#               - 1.0
#               - 1.0
#           mesh_bounds:
#             - - 0.0
#               - 6.0
#               - 0.0
#               - 6.0
#               - 0.0
#               - 2.0
#           mesh_center:
#             - - 3.0
#               - 3.0
#               - 1.0
#       - name: 06_color_scalars.vtk
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/06_color_scalars.vtk
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 5
#           number_of_cells:
#             - 2
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - lut
#           mesh_bounds:
#             - - -1.5
#               - 1.5
#               - -1.5
#               - 1.5
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 0.0
#               - 0.0
#               - 0.0
#       - name: hello.vtk
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/hello.vtk
#         metadata:
#           dataset_type:
#             - PolyData
#           number_of_points:
#             - 22
#           number_of_cells:
#             - 15
#           number_of_lines:
#             - 15
#           mesh_bounds:
#             - - 0.0
#               - 9.0
#               - 0.0
#               - 2.0
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 4.5
#               - 1.0
#               - 0.0
#       - name: 04_rectilinear.vtk
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/04_rectilinear.vtk
#         metadata:
#           dataset_type:
#             - RectilinearGrid
#           number_of_points:
#             - 40
#           number_of_cells:
#             - 27
#           number_of_arrays:
#             - 4
#           array_names:
#             - cell_data_array_names:
#                 - pressure1
#                 - pressure2
#               point_data_array_names:
#                 - temp1
#                 - temp2
#           dimensions:
#             - - 10
#               - 4
#               - 1
#           mesh_bounds:
#             - - 0.0
#               - 1.0
#               - 0.0
#               - 2.0
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 0.5
#               - 1.0
#               - 0.0
#       - name: 06_unstructured.vtk
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/06_unstructured.vtk
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 42
#           number_of_cells:
#             - 12
#           number_of_arrays:
#             - 2
#           array_names:
#             - cell_data_array_names:
#                 - mat_id
#               point_data_array_names:
#                 - node_groups
#           mesh_bounds:
#             - - 1.2999999523162842
#               - 1.5
#               - 0.800000011920929
#               - 1.0
#               - 0.0
#               - 0.5
#           mesh_center:
#             - - 1.399999976158142
#               - 0.9000000059604645
#               - 0.25
#       - name: polyEx0.vtp
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/polyEx0.vtp
#         metadata:
#           dataset_type:
#             - PolyData
#           number_of_points:
#             - 8
#           number_of_cells:
#             - 6
#           number_of_arrays:
#             - 3
#           array_names:
#             - cell_data_array_names:
#                 - cell_scalars
#                 - cell_normals
#               point_data_array_names:
#                 - my_scalars
#           mesh_bounds:
#             - - 0.0
#               - 1.0
#               - 0.0
#               - 1.0
#               - 0.0
#               - 1.0
#           mesh_center:
#             - - 0.5
#               - 0.5
#               - 0.5
#       - name: Bunny.vtp
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/Bunny.vtp
#         metadata:
#           dataset_type:
#             - PolyData
#           number_of_points:
#             - 872
#           number_of_cells:
#             - 1502
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - Normals
#           mesh_bounds:
#             - - -0.13155962526798248
#               - 0.18016336858272552
#               - -0.12048563361167908
#               - 0.18769524991512299
#               - -0.14300920069217682
#               - 0.09850578755140305
#           mesh_center:
#             - - 0.02430187165737152
#               - 0.033604808151721954
#               - -0.022251706570386887
#       - name: RectilinearGrid.vtr
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/RectilinearGrid.vtr
#         metadata:
#           dataset_type:
#             - RectilinearGrid
#           number_of_points:
#             - 545025
#           number_of_cells:
#             - 524288
#           number_of_arrays:
#             - 9
#           array_names:
#             - cell_data_array_names:
#                 - Pressure
#                 - Void Volume Fraction
#                 - X Velocity
#                 - Y Velocity
#                 - Z Velocity
#                 - Volume Fraction for Armor Plate
#                 - Mass for Armor Plate
#                 - Volume Fraction for Body, Nose
#                 - Mass for Body, Nose
#           dimensions:
#             - - 129
#               - 65
#               - 65
#           mesh_bounds:
#             - - -7.5
#               - 4.0
#               - -3.0
#               - 3.0
#               - -3.0
#               - 3.0
#           mesh_center:
#             - - -1.75
#               - 0.0
#               - 0.0
#       - name: pressure_20_1.vtr
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/pressure_20/pressure_20_1.vtr
#         metadata:
#           dataset_type:
#             - RectilinearGrid
#           number_of_points:
#             - 210
#           number_of_cells:
#             - 120
#           number_of_arrays:
#             - 3
#           array_names:
#             - cell_data_array_names:
#                 - vtkGhostTypes
#                 - pressure
#               field_data_array_names:
#                 - TimeValue
#           dimensions:
#             - - 5
#               - 7
#               - 6
#           mesh_bounds:
#             - - 2.0
#               - 6.0
#               - -1.0
#               - 5.0
#               - -1.0
#               - 4.0
#           mesh_center:
#             - - 4.0
#               - 2.0
#               - 1.5
#       - name: pressure_20_0.vtr
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/pressure_20/pressure_20_0.vtr
#         metadata:
#           dataset_type:
#             - RectilinearGrid
#           number_of_points:
#             - 252
#           number_of_cells:
#             - 150
#           number_of_arrays:
#             - 3
#           array_names:
#             - cell_data_array_names:
#                 - vtkGhostTypes
#                 - pressure
#               field_data_array_names:
#                 - TimeValue
#           dimensions:
#             - - 6
#               - 7
#               - 6
#           mesh_bounds:
#             - - -1.0
#               - 4.0
#               - -1.0
#               - 5.0
#               - -1.0
#               - 4.0
#           mesh_center:
#             - - 1.5
#               - 2.0
#               - 1.5
#       - name: StructuredGrid.vts
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/StructuredGrid.vts
#         metadata:
#           dataset_type:
#             - StructuredGrid
#           number_of_points:
#             - 648
#           number_of_cells:
#             - 440
#           number_of_arrays:
#             - 3
#           array_names:
#             - point_data_array_names:
#                 - Density
#                 - Momentum
#                 - StagnationEnergy
#           dimensions:
#             - - 6
#               - 12
#               - 9
#           mesh_bounds:
#             - - 0.0
#               - 6.365341663360596
#               - -5.144453048706055
#               - 5.144453048706055
#               - 23.37380027770996
#               - 32.894798278808594
#           mesh_center:
#             - - 3.182670831680298
#               - 0.0
#               - 28.134299278259277
#       - name: vox8_binary_inline_zlib.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/vox8_binary_inline_zlib.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 27
#           number_of_cells:
#             - 8
#           number_of_arrays:
#             - 12
#           array_names:
#             - cell_data_array_names:
#                 - scalars
#                 - cRamp1
#                 - cRamp2
#                 - cVects
#                 - cv2
#               point_data_array_names:
#                 - scalars
#                 - mytest
#                 - xRamp
#                 - yRamp
#                 - zRamp
#                 - outVect
#                 - vect2
#           mesh_bounds:
#             - - 0.0
#               - 2.0
#               - 0.0
#               - 2.0
#               - 0.0
#               - 2.0
#           mesh_center:
#             - - 1.0
#               - 1.0
#               - 1.0
#       - name: ugridex.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ugridex.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 27
#           number_of_cells:
#             - 12
#           number_of_arrays:
#             - 2
#           array_names:
#             - cell_data_array_names:
#                 - nmax
#               point_data_array_names:
#                 - csum
#           mesh_bounds:
#             - - 0.0
#               - 2.0
#               - 0.0
#               - 1.0
#               - 0.0
#               - 6.0
#           mesh_center:
#             - - 1.0
#               - 0.5
#               - 3.0
#       - name: 01_raw_binary_int64.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/01_raw_binary_int64.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 64
#           number_of_cells:
#             - 162
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - m
#           mesh_bounds:
#             - - 0.0
#               - 1.0
#               - 0.0
#               - 1.0
#               - 0.0
#               - 1.0
#           mesh_center:
#             - - 0.5
#               - 0.5
#               - 0.5
#       - name: test_mesh.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/test_mesh.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 7
#           number_of_cells:
#             - 5
#           number_of_arrays:
#             - 4
#           array_names:
#             - cell_data_array_names:
#                 - cell_index
#                 - cell_func_values
#               point_data_array_names:
#                 - point_index
#                 - function
#           mesh_bounds:
#             - - 0.0
#               - 2.0
#               - 0.0
#               - 1.0
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 1.0
#               - 0.5
#               - 0.0
#       - name: fire_ug.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/fire_ug.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 12323
#           number_of_cells:
#             - 10462
#           number_of_arrays:
#             - 6
#           array_names:
#             - point_data_array_names:
#                 - t
#                 - uvw
#                 - u
#                 - v
#                 - w
#                 - mfrac
#           mesh_bounds:
#             - - 0.0
#               - 6.0
#               - 0.0
#               - 2.5
#               - 0.0
#               - 2.3999998569488525
#           mesh_center:
#             - - 3.0
#               - 1.25
#               - 1.1999999284744263
#       - name: 02_raw_compressed.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/02_raw_compressed.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 64
#           number_of_cells:
#             - 162
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - m
#           mesh_bounds:
#             - - 0.0
#               - 1.0
#               - 0.0
#               - 1.0
#               - 0.0
#               - 1.0
#           mesh_center:
#             - - 0.5
#               - 0.5
#               - 0.5
#       - name: vox8_binary_inline.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/vox8_binary_inline.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 27
#           number_of_cells:
#             - 8
#           number_of_arrays:
#             - 12
#           array_names:
#             - cell_data_array_names:
#                 - scalars
#                 - cRamp1
#                 - cRamp2
#                 - cVects
#                 - cv2
#               point_data_array_names:
#                 - scalars
#                 - mytest
#                 - xRamp
#                 - yRamp
#                 - zRamp
#                 - outVect
#                 - vect2
#           mesh_bounds:
#             - - 0.0
#               - 2.0
#               - 0.0
#               - 2.0
#               - 0.0
#               - 2.0
#           mesh_center:
#             - - 1.0
#               - 1.0
#               - 1.0
#       - name: vox8_ascii.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/vox8_ascii.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 27
#           number_of_cells:
#             - 8
#           number_of_arrays:
#             - 12
#           array_names:
#             - cell_data_array_names:
#                 - scalars
#                 - cRamp1
#                 - cRamp2
#                 - cVects
#                 - cv2
#               point_data_array_names:
#                 - scalars
#                 - mytest
#                 - xRamp
#                 - yRamp
#                 - zRamp
#                 - outVect
#                 - vect2
#           mesh_bounds:
#             - - 0.0
#               - 2.0
#               - 0.0
#               - 2.0
#               - 0.0
#               - 2.0
#           mesh_center:
#             - - 1.0
#               - 1.0
#               - 1.0
#       - name: 00_raw_binary.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/00_raw_binary.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 64
#           number_of_cells:
#             - 162
#           number_of_arrays:
#             - 1
#           array_names:
#             - point_data_array_names:
#                 - m
#           mesh_bounds:
#             - - 0.0
#               - 1.0
#               - 0.0
#               - 1.0
#               - 0.0
#               - 1.0
#           mesh_center:
#             - - 0.5
#               - 0.5
#               - 0.5
#       - name: vox8_binary_appended.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/vox8_binary_appended.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 27
#           number_of_cells:
#             - 8
#           number_of_arrays:
#             - 12
#           array_names:
#             - cell_data_array_names:
#                 - scalars
#                 - cRamp1
#                 - cRamp2
#                 - cVects
#                 - cv2
#               point_data_array_names:
#                 - scalars
#                 - mytest
#                 - xRamp
#                 - yRamp
#                 - zRamp
#                 - outVect
#                 - vect2
#           mesh_bounds:
#             - - 0.0
#               - 2.0
#               - 0.0
#               - 2.0
#               - 0.0
#               - 2.0
#           mesh_center:
#             - - 1.0
#               - 1.0
#               - 1.0
#       - name: triangle_mesh_linear.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/triangle_mesh_linear.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 8
#           number_of_cells:
#             - 6
#           number_of_arrays:
#             - 3
#           array_names:
#             - cell_data_array_names:
#                 - node_max
#               point_data_array_names:
#                 - pressure
#                 - velocity
#           mesh_bounds:
#             - - 0.0
#               - 2.0
#               - 0.0
#               - 2.0
#               - 0.0
#               - 0.0
#           mesh_center:
#             - - 1.0
#               - 1.0
#               - 0.0
#       - name: 001.vtu
# ...
#               - -12.0
#               - -0.3924649953842163
#               - -5.200829982757568
#               - 2.5329198837280273
#           mesh_center:
#             - - 3.3689398765563965
#               - -6.196232497692108
#               - -1.3339550495147705
#       - name: ex-blow_5_0_1.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_0_1.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 81
#           number_of_cells:
#             - 116
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 6.737879753112793
#               - -12.0
#               - -0.3947420120239258
#               - 1.02961003780365
#               - 7.254090309143066
#           mesh_center:
#             - - 3.3689398765563965
#               - -6.197371006011963
#               - 4.141850173473358
#       - name: ex-blow_5_0_7.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_0_7.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 80
#           number_of_cells:
#             - 116
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 6.710299968719482
#               - 24.272518157958984
#               - 36.0
#               - 0.007290000095963478
#               - 6.137589931488037
#           mesh_center:
#             - - 3.355149984359741
#               - 30.136259078979492
#               - 3.0724399657920003
#       - name: ex-blow_5_1_6.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_1_6.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 37
#           number_of_cells:
#             - 15
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 7.0
#               - 0.0
#               - 24.0
#               - -3.8499999046325684
#               - 6.019000053405762
#           mesh_center:
#             - - 3.5
#               - 12.0
#               - 1.0845000743865967
#       - name: ex-blow_5_0_5.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_0_5.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 96
#           number_of_cells:
#             - 116
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 6.530529975891113
#               - 23.30864906311035
#               - 24.826541900634766
#               - -3.6537070274353027
#               - 3.6471240520477295
#           mesh_center:
#             - - 3.2652649879455566
#               - 24.06759548187256
#               - -0.003291487693786621
#       - name: ex-blow_5_1_1.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_1_1.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 28
#           number_of_cells:
#             - 16
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 5.0
#               - 5.0
#               - 7.442180156707764
#               - 7.934120178222656
#               - 5.243100166320801
#               - 6.529600143432617
#           mesh_center:
#             - - 5.0
#               - 7.68815016746521
#               - 5.886350154876709
#       - name: ex-blow_5_1_5.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_1_5.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 42
#           number_of_cells:
#             - 21
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 5.0
#               - 5.0
#               - 7.743239879608154
#               - 8.157979965209961
#               - 5.0
#               - 7.684000015258789
#           mesh_center:
#             - - 5.0
#               - 7.950609922409058
#               - 6.3420000076293945
#       - name: ex-blow_5_0_6.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_0_6.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 81
#           number_of_cells:
#             - 116
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 6.710299968719482
#               - 24.16718101501465
#               - 36.0
#               - -5.999469757080078
#               - 0.9110809564590454
#           mesh_center:
#             - - 3.355149984359741
#               - 30.083590507507324
#               - -2.5441944003105164
#       - name: ex-blow_5_1_7.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_1_7.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 33
#           number_of_cells:
#             - 17
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 7.0
#               - 11.25
#               - 26.0
#               - -3.8499999046325684
#               - 6.0
#           mesh_center:
#             - - 3.5
#               - 18.625
#               - 1.0750000476837158
#       - name: ex-blow_5_1_4.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_1_4.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 21
#           number_of_cells:
#             - 11
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 5.0
#               - 7.853549957275391
#               - 8.154339790344238
#               - 6.019000053405762
#               - 7.853599548339844
#           mesh_center:
#             - - 2.5
#               - 8.003944873809814
#               - 6.936299800872803
#       - name: ex-blow_5_1_3.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_1_3.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 34
#           number_of_cells:
#             - 17
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 5.0
#               - 7.449429988861084
#               - 7.964890003204346
#               - 6.387399673461914
#               - 8.0
#           mesh_center:
#             - - 2.5
#               - 7.707159996032715
#               - 7.193699836730957
#       - name: ex-blow_5_0_4.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_0_4.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 83
#           number_of_cells:
#             - 116
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 7.161890029907227
#               - 11.430950164794922
#               - 23.945070266723633
#               - -3.8500001430511475
#               - 6.0
#           mesh_center:
#             - - 3.5809450149536133
#               - 17.688010215759277
#               - 1.0749999284744263
#       - name: ex-blow_5_1_0.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_1_0.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 39
#           number_of_cells:
#             - 17
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 7.0
#               - -2.0
#               - 8.0
#               - -3.8499999046325684
#               - 6.393500328063965
#           mesh_center:
#             - - 3.5
#               - 3.0
#               - 1.2717502117156982
#       - name: ex-blow_5_1_2.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_1_2.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 29
#           number_of_cells:
#             - 15
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 5.0
#               - 0.0
#               - 7.6915998458862305
#               - 5.0
#               - 8.0
#           mesh_center:
#             - - 2.5
#               - 3.8457999229431152
#               - 6.5
#       - name: ex-blow_5_0_3.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_0_3.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 83
#           number_of_cells:
#             - 116
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 7.161890029907227
#               - -0.020428001880645752
#               - 12.578660011291504
#               - -3.8499999046325684
#               - 7.494060039520264
#           mesh_center:
#             - - 3.5809450149536133
#               - 6.279116004705429
#               - 1.8220300674438477
#       - name: ex-blow_5_0_2.vtu
#         path: /home/sarbani/harvester-curator/darus_data_harvester/example/harvester_related/example_input_folder/ex-blow_5/ex-blow_5_0_2.vtu
#         metadata:
#           dataset_type:
#             - UnstructuredGrid
#           number_of_points:
#             - 96
#           number_of_cells:
#             - 116
#           number_of_arrays:
#             - 8
#           array_names:
#             - cell_data_array_names:
#                 - GlobalElementId
#                 - PedigreeElementId
#                 - ObjectId
#                 - vtkOriginalCellIds
#               point_data_array_names:
#                 - GlobalNodeId
#                 - PedigreeNodeId
#                 - DISPLACEMENT_
#                 - THICKNESS
#           mesh_bounds:
#             - - 0.0
#               - 6.588759899139404
#               - -1.045849084854126
#               - 0.46295398473739624
#               - -1.8193100690841675
#               - 5.744719982147217
#           mesh_center:
#             - - 3.294379949569702
#               - -0.29144755005836487
#               - 1.9627049565315247
# __source__:
#   root: SuperGroup
